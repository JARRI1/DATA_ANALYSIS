# %% [markdown]
# ## EDA Of The Tabular Sheet

# %% [markdown]
# In this EDA we take a small dataframe of tabular sheet/ result sheet and analysis all the given data

# %% [markdown]
# To start the EDA on the tabular sheet we make environment using miniconda and install all the libraries that we need in the EDA
# such as:
# 1. Python 3.10
# 2. pandas
# 3. seaborn
# 4. numpy or etc

# %%
# import all the libraries
import pandas as pd 
import seaborn as sns 
import numpy as np 
import ydata_profiling as yd
import matplotlib.pyplot as py

# %%
# set the option to be maximun for rows and columns and also hide all warnings 
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

# hide all the warnings
import warnings 
warnings.filterwarnings("ignore")

# %%
# import the dataframe for the EDA
df=pd.read_csv("../DATASETS/tabular_sheet.csv")

# %%
# to check the dataframe complete over view  
df
# Out:
#     Student Id  File #               Student Name  Computer Science  English  \
# 0       127863  907656         Abeeha Fatima Amir              20.5     32.5
# 1       344027  917854              Abreer Ayesha              19.0     31.0
# 2       415787  918321                Aleesha Zia              22.5     37.5
# 3       620098  908397              Alleha Fatima              22.0     24.5
# 4       641021  928555                 Aqsa Ilyas              22.0     27.0
# 5       657334  923617               Asawer Nayab              22.0     34.5
# 6       825932  928366                Asma Khalid               9.0      8.5
# 7       204766  906025                 Aswa Irfan              21.0     32.0
# 8       756188  925541               Bushra Qadir              24.0     37.0
# 9       204935  911802          Dua Nouman Majeed              24.5     38.5
# 10      819011  928363                 Inaya Khan              19.5     33.5
# ...

# %%
# look top first three rows
df.head(3)
# Out:
#    Student Id  File #        Student Name  Computer Science  English  \
# 0      127863  907656  Abeeha Fatima Amir              20.5     32.5
# 1      344027  917854       Abreer Ayesha              19.0     31.0
# 2      415787  918321         Aleesha Zia              22.5     37.5
#
#    Geography  History  Islamiyat - Ethics  Mathematics  Science  Urdu  \
# 0       13.5     15.5                13.5         21.5     17.5  34.0
# 1       13.5     10.0                10.0         20.3     21.0  33.5
# 2       18.5     20.0                17.0         23.1     29.0  37.0
#
#    Obtained Marks  Max Marks  Percentage
# 0           168.5        235       71.70
# 1           158.3        235       67.36
# 2           204.6        235       87.06

# %%
# check the columns in the dataset
df.columns
# Out:
# Index(['Student Id', 'File #', 'Student Name', 'Computer Science', 'English',
#        'Geography', 'History', 'Islamiyat - Ethics', 'Mathematics', 'Science',
#        'Urdu', 'Obtained Marks', 'Max Marks', 'Percentage'],
#       dtype='object')

# %%
# to check the numbers of rows and columns in dataframe
df.shape
# Out:
# (25, 14)

# %%
print(f'the number of rows are = {df.shape[0]}')
print(f'the number of columns are = {df.shape[1]}')
# Out:
# the number of rows are = 25
# the number of columns are = 14

# %%
# to get the info of the dataframe over view 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student Id          25 non-null     int64
#  1   File #              25 non-null     int64
#  2   Student Name        25 non-null     object
#  3   Computer Science    25 non-null     float64
#  4   English             25 non-null     float64
#  5   Geography           25 non-null     float64
#  6   History             25 non-null     float64
#  7   Islamiyat - Ethics  25 non-null     float64
#  8   Mathematics         25 non-null     float64
#  9   Science             25 non-null     float64
#  10  Urdu                25 non-null     float64
#  11  Obtained Marks      25 non-null     float64
#  12  Max Marks           25 non-null     int64
#  13  Percentage          25 non-null     float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 2.9+ KB

# %%
# To check the numeric data values 
df.describe()
# Out:
#           Student Id         File #  Computer Science    English  Geography  \
# count      25.000000      25.000000         25.000000  25.000000  25.000000
# mean   508786.320000  918979.440000         20.660000  29.540000  15.140000
# std    262566.780883    8541.643426          2.964091   7.404841   3.869001
# min    127863.000000  906025.000000          9.000000   8.500000   3.500000
# 25%    276582.000000  911493.000000         19.500000  27.000000  13.500000
# 50%    620098.000000  920290.000000         21.000000  32.000000  16.500000
# 75%    767606.000000  928284.000000         22.500000  34.500000  18.000000
# max    842710.000000  928555.000000         24.500000  38.500000  20.000000
#
#          History  Islamiyat - Ethics  Mathematics    Science       Urdu  \
# count  25.000000           25.000000    25.000000  25.000000  25.000000
# mean   16.720000           13.160000    19.696000  23.420000  35.200000
# ...

# %%
# check the missing values
df.isnull().sum()
# Out:
# Student Id            0
# File #                0
# Student Name          0
# Computer Science      0
# English               0
# Geography             0
# History               0
# Islamiyat - Ethics    0
# Mathematics           0
# Science               0
# Urdu                  0
# Obtained Marks        0
# Max Marks             0
# Percentage            0
# dtype: int64

# %%
# the number of unique values in dataframe 
df.nunique()
# Out:
# Student Id            25
# File #                25
# Student Name          25
# Computer Science      11
# English               20
# Geography             18
# History               13
# Islamiyat - Ethics    21
# Mathematics           24
# Science               21
# Urdu                  11
# Obtained Marks        25
# Max Marks              1
# Percentage            25
# dtype: int64

# %%
# to determine the maximun marks in all subjects 
df[['Computer Science', 'English',
       'Geography', 'History', 'Islamiyat - Ethics', 'Mathematics', 'Science',
       'Urdu', 'Obtained Marks', 'Max Marks', 'Percentage']].max()
# Out:
# Computer Science       24.50
# English                38.50
# Geography              20.00
# History                20.00
# Islamiyat - Ethics     22.00
# Mathematics            27.60
# Science                33.50
# Urdu                   37.50
# Obtained Marks        221.10
# Max Marks             235.00
# Percentage             94.09
# dtype: float64

# %%
# to determine the minimum marks in all subjects
df[['Computer Science', 'English',
       'Geography', 'History', 'Islamiyat - Ethics', 'Mathematics', 'Science',
       'Urdu', 'Obtained Marks', 'Max Marks', 'Percentage']].min()
# Out:
# Computer Science        9.00
# English                 8.50
# Geography               3.50
# History                 5.50
# Islamiyat - Ethics      2.50
# Mathematics             0.00
# Science                 8.00
# Urdu                   20.00
# Obtained Marks         58.00
# Max Marks             235.00
# Percentage             24.68
# dtype: float64

# %%
# to determine the minimum marks in all subjects
df[['Computer Science', 'English',
       'Geography', 'History', 'Islamiyat - Ethics', 'Mathematics', 'Science',
       'Urdu', 'Obtained Marks', 'Max Marks', 'Percentage']].value_counts()
# Out:
# Computer Science  English  Geography  History  Islamiyat - Ethics  Mathematics  Science  Urdu  Obtained Marks  Max Marks  Percentage
# 9.0               8.5      3.5        5.5      3.5                 0.0          8.0      20.0  58.0            235        24.68         1
# 21.0              29.5     17.0       17.0     14.0                22.0         20.5     35.0  176.0           235        74.89         1
# 24.0              37.0     20.0       20.0     22.0                24.1         32.0     36.5  215.6           235        91.74         1
#                   36.0     19.5       20.0     15.5                25.6         27.5     37.5  205.6           235        87.49         1
# 22.5              37.5     18.5       20.0     17.0                23.1         29.0     37.0  204.6           235        87.06         1
#                   36.0     17.5       17.0     16.0                15.1         28.0     36.5  188.6           235        80.26         1
# ...

# %%
# to rename the columns in the datsets
df.rename(columns={'Computer Science':'Computer_Science'}, inplace=True)

# %%
# to sort the data by the names
df.sort_values(by='Student Name')
# Out:
#     Student Id  File #               Student Name  Computer_Science  English  \
# 0       127863  907656         Abeeha Fatima Amir              20.5     32.5
# 1       344027  917854              Abreer Ayesha              19.0     31.0
# 2       415787  918321                Aleesha Zia              22.5     37.5
# 3       620098  908397              Alleha Fatima              22.0     24.5
# 4       641021  928555                 Aqsa Ilyas              22.0     27.0
# 5       657334  923617               Asawer Nayab              22.0     34.5
# 6       825932  928366                Asma Khalid               9.0      8.5
# 7       204766  906025                 Aswa Irfan              21.0     32.0
# 8       756188  925541               Bushra Qadir              24.0     37.0
# 9       204935  911802          Dua Nouman Majeed              24.5     38.5
# 10      819011  928363                 Inaya Khan              19.5     33.5
# ...

# %%
#to make HTML files
profile = yd.ProfileReport(df)
profile.to_file(output_file="./ydata_df.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
